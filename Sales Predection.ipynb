# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split

# %%
data=pd.read_csv("advertising.csv")
data
# Out:
#         TV  Radio  Newspaper  Sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3   12.0
# 3    151.5   41.3       58.5   16.5
# 4    180.8   10.8       58.4   17.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1   14.0
# 197  177.0    9.3        6.4   14.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   18.4
#
# [200 rows x 4 columns]

# %%
data.describe()
# Out:
#                TV       Radio   Newspaper       Sales
# count  200.000000  200.000000  200.000000  200.000000
# mean   147.042500   23.264000   30.554000   15.130500
# std     85.854236   14.846809   21.778621    5.283892
# min      0.700000    0.000000    0.300000    1.600000
# 25%     74.375000    9.975000   12.750000   11.000000
# 50%    149.750000   22.900000   25.750000   16.000000
# 75%    218.825000   36.525000   45.100000   19.050000
# max    296.400000   49.600000  114.000000   27.000000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   TV         200 non-null    float64
#  1   Radio      200 non-null    float64
#  2   Newspaper  200 non-null    float64
#  3   Sales      200 non-null    float64
# dtypes: float64(4)
# memory usage: 6.4 KB

# %% [markdown]
# There is no non null values in the dataset so we don't need to correct it.

# %%
tv=data["TV"].mean()
radio=data["Radio"].mean()
np=data["Newspaper"].mean()
sale=data["Sales"].mean()

# %%
tv
# Out:
# 147.0425

# %%
radio
# Out:
# 23.264000000000006

# %%
np
# Out:
# 30.553999999999995

# %%
sale
# Out:
# 15.130500000000001

# %%
data.duplicated().sum()
# Out:
# 0

# %%
sns.histplot(x=data["TV"],bins=20)
plt.xlabel("TV")
plt.ylabel("Count")
plt.title("TV Distribution")
plt.show()
# Out:
# C:\Users\Ajith G\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.histplot(x=data["TV"],y=data["Sales"])
plt.xlabel("TV")
plt.ylabel("Sales")
plt.title("TV Distribution vs sales")
plt.show()
# Out:
# C:\Users\Ajith G\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Ajith G\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
plt.boxplot(data["TV"])
plt.xlabel("TV")
plt.ylabel("Sales")
plt.title("Boxplot TV vs Sales")
plt.show()

# %%
plt.scatter(data['TV'], data['Sales'])
plt.title("Scatter Plot TV vs Sales")
plt.show()

# %%
sns.histplot(x=data["Radio"],bins=20)
plt.xlabel("Radio")
plt.ylabel("Count")
plt.title("Radio Distribution")
plt.show()
# Out:
# C:\Users\Ajith G\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.histplot(x=data["Radio"],y=data["Sales"])
plt.xlabel("Radio")
plt.ylabel("Sales")
plt.title("Radio Distribution vs Sales")
plt.show()
# Out:
# C:\Users\Ajith G\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Ajith G\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
plt.boxplot(data["Radio"])
plt.xlabel("Radio")
plt.ylabel("Sales")
plt.title("Boxplot Radio vs Sales")
plt.show()

# %%
plt.scatter(data['Radio'], data['Sales'])
plt.title("Scatter Plot Radio vs Sales")
plt.show()

# %%
sns.histplot(x=data["Newspaper"],bins=20)
plt.xlabel("Newspaper")
plt.ylabel("Count")
plt.title("Newspaper Distribution")
plt.show()
# Out:
# C:\Users\Ajith G\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.histplot(x=data["Newspaper"],y=data["Sales"])
plt.xlabel("Newspaper")
plt.ylabel("Sales")
plt.title("Newspaper Distribution vs sales")
plt.show()
# Out:
# C:\Users\Ajith G\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Ajith G\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
plt.boxplot(data["Newspaper"])
plt.xlabel("Newspaper")
plt.ylabel("Sales")
plt.title("Boxplot Newspaper vs sales")
plt.show()

# %%
plt.scatter(data['Newspaper'], data['Sales'])
plt.title("Scatter Plot Newspaper vs Sales")
plt.show()

# %%
data.corr()
# Out:
#                  TV     Radio  Newspaper     Sales
# TV         1.000000  0.054809   0.056648  0.901208
# Radio      0.054809  1.000000   0.354104  0.349631
# Newspaper  0.056648  0.354104   1.000000  0.157960
# Sales      0.901208  0.349631   0.157960  1.000000

# %%
sns.heatmap(data.corr(), cmap="YlGnBu", annot = True)
plt.show()
